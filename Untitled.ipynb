# %%
from keras.models import load_model
from keras import backend as K
import numpy as np
from keras.preprocessing import image
img_pred=image.load_img('data/abc.jpg', target_size=(150,150))
img_pred = image.img_to_array(img_pred)
img_pred = np.expand_dims(img_pred, axis=0)
model2 = load_model('my_model.h5')
rslt = model2.predict(img_pred)
if rslt[0][0] == 1:
    prediction = 'dog'
else :
    prediction = 'cat'
print(prediction)
# Out:
# WARNING:tensorflow:From /home/bibhuti/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/bibhuti/.local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/bibhuti/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# cat

# %%
import base64
 
with open("data/abc.jpg", "rb") as imageFile:
    str = base64.b64encode(imageFile.read())
    print(str)
# Out:
# b'...'

# %%
fh = open("abc1.jpg", "wb")
fh.write(base64.b64encode(bytes(str, 'utf-8')))
fh.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-4afa30286020> in <module>
#       1 fh = open("abc1.jpg", "wb")
# ----> 2 fh.write(base64.b64encode(bytes(str, 'utf-8')))
#       3 fh.close()
#
# TypeError: encoding without a string argument

# %%
import base64 
from keras.preprocessing import image
image = open('data/abc.jpg', 'rb') 
image_read = image.read() 
image_64_encode = base64.encodestring(image_read) 
# image_64_decode = base64.decodestring(image_64_encode) 
# image_result = open('abc1.jpg', 'wb') 
# image_result.write(image_64_decode)
# Out:
# /home/bibhuti/.local/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: encodestring() is a deprecated alias since 3.1, use encodebytes()
#   """

# %%
# Out:
# /home/bibhuti/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: decodestring() is a deprecated alias since Python 3.1, use decodebytes()
#   """Entry point for launching an IPython kernel.

# %%
img_pred = image.load_img('abc1.jpg', target_size=(150,150))
img_pred = image.img_to_array(img_pred)
img_pred = np.expand_dims(img_pred, axis=0)
model = load_model('my_model_final.h5')
rslt = model.predict(img_pred)
if rslt[0][0] == 1:
    prediction = 'dog'
else :
    prediction = 'cat'

# %%
print(prediction)
# Out:
# dog
